# %%
# run imports

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read in data

police = pd.read_csv('fatal-police-shootings-data.csv')

# %%
police.head()
# Out:
#    id                name        date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke  2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  longitude  latitude  is_geocoding_exact
# ...

# %%
police.tail()
# Out:
#         id           name        date manner_of_death    armed   age gender  \
# 6027  6573            NaN  2021-02-06            shot      gun   NaN      M
# 6028  6584            NaN  2021-02-06            shot      gun  23.0      M
# 6029  6586  Anthony Greco  2021-02-06            shot      gun  29.0      M
# 6030  6567            NaN  2021-02-07            shot  hatchet   NaN      M
# 6031  6570            NaN  2021-02-07            shot      gun   NaN      M
#
#      race           city state  signs_of_mental_illness threat_level  \
# 6027  NaN       Sarasota    FL                    False       attack
# 6028  NaN           Mesa    AZ                     True        other
# 6029  NaN        Phoenix    AZ                    False       attack
# 6030  NaN  Lacy Lakeview    TX                    False        other
# 6031  NaN     Bettendorf    IA                    False        other
#
#              flee  body_camera  longitude  latitude  is_geocoding_exact
# ...

# %%
# check for null values

police_s.isnull().sum()
# Out:
# id                           0
# name                       230
# date                         0
# manner_of_death              0
# armed                      210
# age                        276
# gender                       1
# race                       623
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                       344
# body_camera                  0
# longitude                  294
# latitude                   294
# is_geocoding_exact           0
# dtype: int64

# %%
police_s.shape
# Out:
# (6032, 17)

# %%
police_s.describe()
# Out:
#                 id          age    longitude     latitude
# count  6032.000000  5756.000000  5738.000000  5738.000000
# mean   3344.378647    37.167477   -97.233456    36.652464
# std    1887.236003    13.058384    16.626978     5.377241
# min       3.000000     6.000000  -158.137000    19.498000
# 25%    1706.750000    27.000000  -112.116750    33.469250
# 50%    3350.500000    35.000000   -94.385500    36.097000
# 75%    4989.250000    46.000000   -83.069750    39.972000
# max    6587.000000    91.000000   -68.014000    71.301000

# %%
young = police_s[police_s['age'] < 16]

# %%
young.sort_values(by='age')
# Out:
#         id                  name        date   manner_of_death       armed  \
# 833    980         Jeremy Mardis  2015-11-03              shot     unarmed
# 2907  3229      Kameron Prescott  2017-12-21              shot     unarmed
# 1017  1165           Ciara Meyer  2016-01-11              shot     unarmed
# 1681  1883             Tyre King  2016-09-14              shot  toy weapon
# 3983  4386          Antonio Arce  2019-01-15              shot  toy weapon
# 1588  1776    Jesse James Romero  2016-08-09              shot         gun
# 2804  3117        Jason Ike Pero  2017-11-08              shot       knife
# 435    551           Zane Terryn  2015-06-14              shot         gun
# 3624  3977        Spencer Mendez  2018-08-18              shot         gun
# 2842  3154  Seth William Johnson  2017-11-20              shot       knife
# 2654  2950          Ruben Urbina  2017-09-15              shot     crowbar
# ...
